# %% [markdown]
# # 📌 Extracción

# %%
import requests
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/ingridcristh/challenge2-data-science/refs/heads/main/TelecomX_Data.json'
response = requests.get(url)
data = response.json()
df = pd.DataFrame(data)
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
df = pd.json_normalize(data)
df
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# 1                  No                  No                9                Yes
# 2                  No                  No                4                Yes
# 3                 Yes                  No               13                Yes
# 4                 Yes                  No                3                Yes
# ...               ...                 ...              ...                ...
# 7262               No                  No               13                Yes
# 7263              Yes                  No               22                Yes
# 7264               No                  No                2                Yes
# 7265              Yes                 Yes               67                Yes
# 7266              Yes                 Yes               63                 No
#
#      phone.MultipleLines internet.InternetService  ... internet.OnlineBackup  \
# 0                     No                      DSL  ...                   Yes
# 1                    Yes                      DSL  ...                    No
# 2                     No              Fiber optic  ...                    No
# 3                     No              Fiber optic  ...                   Yes
# 4                     No              Fiber optic  ...                    No
# ...                  ...                      ...  ...                   ...
# 7262                  No                      DSL  ...                    No
# 7263                 Yes              Fiber optic  ...                    No
# 7264                  No                      DSL  ...                   Yes
# 7265                  No                      DSL  ...                    No
# 7266    No phone service                      DSL  ...                   Yes
#
#      internet.DeviceProtection internet.TechSupport internet.StreamingTV  \
# 0                           No                  Yes                  Yes
# 1                           No                   No                   No
# 2                          Yes                   No                   No
# 3                          Yes                   No                  Yes
# 4                           No                  Yes                  Yes
# ...                        ...                  ...                  ...
# 7262                        No                  Yes                   No
# 7263                        No                   No                   No
# 7264                        No                   No                   No
# 7265                       Yes                  Yes                   No
# 7266                       Yes                   No                  Yes
#
#      internet.StreamingMovies account.Contract account.PaperlessBilling  \
# 0                          No         One year                      Yes
# 1                         Yes   Month-to-month                       No
# 2                          No   Month-to-month                      Yes
# 3                         Yes   Month-to-month                      Yes
# 4                          No   Month-to-month                      Yes
# ...                       ...              ...                      ...
# 7262                       No         One year                       No
# 7263                      Yes   Month-to-month                      Yes
# 7264                       No   Month-to-month                      Yes
# 7265                      Yes         Two year                       No
# 7266                      Yes         Two year                       No
#
#      account.PaymentMethod account.Charges.Monthly  account.Charges.Total
# 0             Mailed check                   65.60                  593.3
# 1             Mailed check                   59.90                  542.4
# 2         Electronic check                   73.90                 280.85
# 3         Electronic check                   98.00                1237.85
# 4             Mailed check                   83.90                  267.4
# ...                    ...                     ...                    ...
# 7262          Mailed check                   55.15                  742.9
# 7263      Electronic check                   85.10                 1873.7
# 7264          Mailed check                   50.30                  92.75
# 7265          Mailed check                   67.85                4627.65
# 7266      Electronic check                   59.00                 3707.6
#
# [7267 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
#  13  internet.TechSupport       7267 non-null   object
#  14  internet.StreamingTV       7267 non-null   object
#  15  internet.StreamingMovies   7267 non-null   object
#  16  account.Contract           7267 non-null   object
#  17  account.PaperlessBilling   7267 non-null   object
#  18  account.PaymentMethod      7267 non-null   object
#  19  account.Charges.Monthly    7267 non-null   float64
#  20  account.Charges.Total      7267 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.2+ MB

# %%
for col in df.columns:
  print(f'{col}: {df[col].nunique()}')
  if df[col].nunique() < 50:
    print(df[col].unique())
    print('-' * 50)
# Out:
# customerID: 7267
# Churn: 3
# ['No' 'Yes' '']
# --------------------------------------------------
# customer.gender: 2
# ['Female' 'Male']
# --------------------------------------------------
# customer.SeniorCitizen: 2
# [0 1]
# --------------------------------------------------
# customer.Partner: 2
# ['Yes' 'No']
# --------------------------------------------------
# customer.Dependents: 2
# ['Yes' 'No']
# --------------------------------------------------
# customer.tenure: 73
# phone.PhoneService: 2
# ['Yes' 'No']
# --------------------------------------------------
# phone.MultipleLines: 3
# ['No' 'Yes' 'No phone service']
# --------------------------------------------------
# internet.InternetService: 3
# ['DSL' 'Fiber optic' 'No']
# --------------------------------------------------
# internet.OnlineSecurity: 3
# ['No' 'Yes' 'No internet service']
# --------------------------------------------------
# internet.OnlineBackup: 3
# ['Yes' 'No' 'No internet service']
# --------------------------------------------------
# internet.DeviceProtection: 3
# ['No' 'Yes' 'No internet service']
# --------------------------------------------------
# internet.TechSupport: 3
# ['Yes' 'No' 'No internet service']
# --------------------------------------------------
# internet.StreamingTV: 3
# ['Yes' 'No' 'No internet service']
# --------------------------------------------------
# internet.StreamingMovies: 3
# ['No' 'Yes' 'No internet service']
# --------------------------------------------------
# account.Contract: 3
# ['One year' 'Month-to-month' 'Two year']
# --------------------------------------------------
# account.PaperlessBilling: 2
# ['Yes' 'No']
# --------------------------------------------------
# account.PaymentMethod: 4
# ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']
# --------------------------------------------------
# account.Charges.Monthly: 1585
# account.Charges.Total: 6531

# %%
print("Numero de duplicados", df.duplicated().sum())
# Out:
# Numero de duplicados 0

# %%
print("Numero de Nulos \n", df.isnull().sum())
# Out:
# Numero de Nulos
#  customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %%
df.apply(lambda x: x.astype(str).str.strip() == '').sum()
# Out:
# customerID                     0
# Churn                        224
# customer.gender                0
# customer.SeniorCitizen         0
# customer.Partner               0
# customer.Dependents            0
# customer.tenure                0
# phone.PhoneService             0
# phone.MultipleLines            0
# internet.InternetService       0
# internet.OnlineSecurity        0
# internet.OnlineBackup          0
# internet.DeviceProtection      0
# internet.TechSupport           0
# internet.StreamingTV           0
# internet.StreamingMovies       0
# account.Contract               0
# account.PaperlessBilling       0
# account.PaymentMethod          0
# account.Charges.Monthly        0
# account.Charges.Total         11
# dtype: int64

# %% [markdown]
# ## 🔧 **Transformación**

# %%
df['account.Charges.Total'] = pd.to_numeric(df['account.Charges.Total'], errors='coerce')

# %%
df= df[df['Churn'].str.strip() != '']
print("Número de filas después de eliminar las vacías en 'Churn':", len(df))
# Out:
# Número de filas después de eliminar las vacías en 'Churn': 7043

# %%
df.apply(lambda x: x.astype(str).str.strip() == '').sum()
# Out:
# customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %%
print("Numero de Nulos \n", df.isnull().sum())
# Out:
# Numero de Nulos
#  customerID                    0
# Churn                         0
# customer.gender               0
# customer.SeniorCitizen        0
# customer.Partner              0
# customer.Dependents           0
# customer.tenure               0
# phone.PhoneService            0
# phone.MultipleLines           0
# internet.InternetService      0
# internet.OnlineSecurity       0
# internet.OnlineBackup         0
# internet.DeviceProtection     0
# internet.TechSupport          0
# internet.StreamingTV          0
# internet.StreamingMovies      0
# account.Contract              0
# account.PaperlessBilling      0
# account.PaymentMethod         0
# account.Charges.Monthly       0
# account.Charges.Total        11
# dtype: int64

# %%
df = df.dropna(subset=['account.Charges.Total'])

# %%
print("Numero de Nulos \n", df.isnull().sum())
# Out:
# Numero de Nulos
#  customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %%
df['cuentas_diarias'] = df['account.Charges.Monthly'] / 30
df
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# 1                  No                  No                9                Yes
# 2                  No                  No                4                Yes
# 3                 Yes                  No               13                Yes
# 4                 Yes                  No                3                Yes
# ...               ...                 ...              ...                ...
# 7262               No                  No               13                Yes
# 7263              Yes                  No               22                Yes
# 7264               No                  No                2                Yes
# 7265              Yes                 Yes               67                Yes
# 7266              Yes                 Yes               63                 No
#
#      phone.MultipleLines internet.InternetService  ...  \
# 0                     No                      DSL  ...
# 1                    Yes                      DSL  ...
# 2                     No              Fiber optic  ...
# 3                     No              Fiber optic  ...
# 4                     No              Fiber optic  ...
# ...                  ...                      ...  ...
# 7262                  No                      DSL  ...
# 7263                 Yes              Fiber optic  ...
# 7264                  No                      DSL  ...
# 7265                  No                      DSL  ...
# 7266    No phone service                      DSL  ...
#
#      internet.DeviceProtection internet.TechSupport internet.StreamingTV  \
# 0                           No                  Yes                  Yes
# 1                           No                   No                   No
# 2                          Yes                   No                   No
# 3                          Yes                   No                  Yes
# 4                           No                  Yes                  Yes
# ...                        ...                  ...                  ...
# 7262                        No                  Yes                   No
# 7263                        No                   No                   No
# 7264                        No                   No                   No
# 7265                       Yes                  Yes                   No
# 7266                       Yes                   No                  Yes
#
#      internet.StreamingMovies account.Contract account.PaperlessBilling  \
# 0                          No         One year                      Yes
# 1                         Yes   Month-to-month                       No
# 2                          No   Month-to-month                      Yes
# 3                         Yes   Month-to-month                      Yes
# 4                          No   Month-to-month                      Yes
# ...                       ...              ...                      ...
# 7262                       No         One year                       No
# 7263                      Yes   Month-to-month                      Yes
# 7264                       No   Month-to-month                      Yes
# 7265                      Yes         Two year                       No
# 7266                      Yes         Two year                       No
#
#      account.PaymentMethod account.Charges.Monthly account.Charges.Total  \
# 0             Mailed check                   65.60                593.30
# 1             Mailed check                   59.90                542.40
# 2         Electronic check                   73.90                280.85
# 3         Electronic check                   98.00               1237.85
# 4             Mailed check                   83.90                267.40
# ...                    ...                     ...                   ...
# 7262          Mailed check                   55.15                742.90
# 7263      Electronic check                   85.10               1873.70
# 7264          Mailed check                   50.30                 92.75
# 7265          Mailed check                   67.85               4627.65
# 7266      Electronic check                   59.00               3707.60
#
#       cuentas_diarias
# 0            2.186667
# 1            1.996667
# 2            2.463333
# 3            3.266667
# 4            2.796667
# ...               ...
# 7262         1.838333
# 7263         2.836667
# 7264         1.676667
# 7265         2.261667
# 7266         1.966667
#
# [7032 rows x 22 columns]

# %%
columnas = {                                                        # Diccionario con los nuevos nombres de las columnas.
    'customerID': 'id',
    'customer.gender': 'genero',
    'customer.SeniorCitizen': 'tiene +60',
    'customer.Partner': 'posee_pareja',
    'customer.Dependents': 'posee_dependientes',
    'customer.tenure': 'tiempo_contrato',
    'phone.PhoneService': 'servicio_telefono',
    'phone.MultipleLines': 'multiples_lineas',
    'internet.InternetService': 'tipo_internet',
    'internet.OnlineSecurity': 'seguridad_online',
    'internet.OnlineBackup': 'backup_online',
    'internet.DeviceProtection': 'proteccion_dispositivo',
    'internet.TechSupport': 'soporte_tecnico',
    'internet.StreamingTV': 'streaming_tv',
    'internet.StreamingMovies': 'streaming_peliculas',
    'account.Contract': 'tipo_contrato',
    'account.PaperlessBilling': 'factura_digital',
    'account.PaymentMethod': 'metodo_pago',
    'account.Charges.Monthly': 'valor_mensal',
    'account.Charges.Total': 'total_cobrado'
}
df = df.rename(columns= columnas)
df
# Out:
#               id Churn  genero  tiene +60 posee_pareja posee_dependientes  \
# 0     0002-ORFBO    No  Female          0          Yes                Yes
# 1     0003-MKNFE    No    Male          0           No                 No
# 2     0004-TLHLJ   Yes    Male          0           No                 No
# 3     0011-IGKFF   Yes    Male          1          Yes                 No
# 4     0013-EXCHZ   Yes  Female          1          Yes                 No
# ...          ...   ...     ...        ...          ...                ...
# 7262  9987-LUTYD    No  Female          0           No                 No
# 7263  9992-RRAMN   Yes    Male          0          Yes                 No
# 7264  9992-UJOEL    No    Male          0           No                 No
# 7265  9993-LHIEB    No    Male          0          Yes                Yes
# 7266  9995-HOTOH    No    Male          0          Yes                Yes
#
#       tiempo_contrato servicio_telefono  multiples_lineas tipo_internet  ...  \
# 0                   9               Yes                No           DSL  ...
# 1                   9               Yes               Yes           DSL  ...
# 2                   4               Yes                No   Fiber optic  ...
# 3                  13               Yes                No   Fiber optic  ...
# 4                   3               Yes                No   Fiber optic  ...
# ...               ...               ...               ...           ...  ...
# 7262               13               Yes                No           DSL  ...
# 7263               22               Yes               Yes   Fiber optic  ...
# 7264                2               Yes                No           DSL  ...
# 7265               67               Yes                No           DSL  ...
# 7266               63                No  No phone service           DSL  ...
#
#      proteccion_dispositivo soporte_tecnico streaming_tv streaming_peliculas  \
# 0                        No             Yes          Yes                  No
# 1                        No              No           No                 Yes
# 2                       Yes              No           No                  No
# 3                       Yes              No          Yes                 Yes
# 4                        No             Yes          Yes                  No
# ...                     ...             ...          ...                 ...
# 7262                     No             Yes           No                  No
# 7263                     No              No           No                 Yes
# 7264                     No              No           No                  No
# 7265                    Yes             Yes           No                 Yes
# 7266                    Yes              No          Yes                 Yes
#
#        tipo_contrato factura_digital       metodo_pago valor_mensal  \
# 0           One year             Yes      Mailed check        65.60
# 1     Month-to-month              No      Mailed check        59.90
# 2     Month-to-month             Yes  Electronic check        73.90
# 3     Month-to-month             Yes  Electronic check        98.00
# 4     Month-to-month             Yes      Mailed check        83.90
# ...              ...             ...               ...          ...
# 7262        One year              No      Mailed check        55.15
# 7263  Month-to-month             Yes  Electronic check        85.10
# 7264  Month-to-month             Yes      Mailed check        50.30
# 7265        Two year              No      Mailed check        67.85
# 7266        Two year              No  Electronic check        59.00
#
#      total_cobrado  cuentas_diarias
# 0           593.30         2.186667
# 1           542.40         1.996667
# 2           280.85         2.463333
# 3          1237.85         3.266667
# 4           267.40         2.796667
# ...            ...              ...
# 7262        742.90         1.838333
# 7263       1873.70         2.836667
# 7264         92.75         1.676667
# 7265       4627.65         2.261667
# 7266       3707.60         1.966667
#
# [7032 rows x 22 columns]

# %%
df['Churn'] = df['Churn'].replace({'No': 'No', 'Yes': 'Sí'})
df['genero'] = df['genero'].replace({'Female': 'Femenino', 'Male': 'Masculino'})
df['posee_pareja'] = df['posee_pareja'].replace({'Yes': 'Sí', 'No': 'No'})
df['posee_dependientes'] = df['posee_dependientes'].replace({'Yes': 'Sí', 'No': 'No'})
df['servicio_telefono'] = df['servicio_telefono'].replace({'Yes': 'Sí', 'No': 'No'})
df['multiples_lineas'] = df['multiples_lineas'].replace({'No': 'No', 'Yes': 'Sí', 'No phone service': 'Sin servicio de teléfono'})
df['tipo_internet'] = df['tipo_internet'].replace({'No': 'No'})
df['tipo_contrato'] = df['tipo_contrato'].replace({'One year': 'Anual', 'Month-to-month': 'Mensual', 'Two year': 'Bienal'})
df.head()
# Out:
#            id Churn     genero  tiene +60 posee_pareja posee_dependientes  \
# 0  0002-ORFBO    No   Femenino          0           Sí                 Sí
# 1  0003-MKNFE    No  Masculino          0           No                 No
# 2  0004-TLHLJ    Sí  Masculino          0           No                 No
# 3  0011-IGKFF    Sí  Masculino          1           Sí                 No
# 4  0013-EXCHZ    Sí   Femenino          1           Sí                 No
#
#    tiempo_contrato servicio_telefono multiples_lineas tipo_internet  ...  \
# 0                9                Sí               No           DSL  ...
# 1                9                Sí               Sí           DSL  ...
# 2                4                Sí               No   Fiber optic  ...
# 3               13                Sí               No   Fiber optic  ...
# 4                3                Sí               No   Fiber optic  ...
#
#   proteccion_dispositivo soporte_tecnico streaming_tv streaming_peliculas  \
# 0                     No             Yes          Yes                  No
# 1                     No              No           No                 Yes
# 2                    Yes              No           No                  No
# 3                    Yes              No          Yes                 Yes
# 4                     No             Yes          Yes                  No
#
#   tipo_contrato factura_digital       metodo_pago valor_mensal total_cobrado  \
# 0         Anual             Yes      Mailed check         65.6        593.30
# 1       Mensual              No      Mailed check         59.9        542.40
# 2       Mensual             Yes  Electronic check         73.9        280.85
# 3       Mensual             Yes  Electronic check         98.0       1237.85
# 4       Mensual             Yes      Mailed check         83.9        267.40
#
#    cuentas_diarias
# 0         2.186667
# 1         1.996667
# 2         2.463333
# 3         3.266667
# 4         2.796667
#
# [5 rows x 22 columns]

# %%
columnas_a_traducir = ['seguridad_online', 'backup_online', 'proteccion_dispositivo', 'soporte_tecnico', 'streaming_tv', 'streaming_peliculas']
mapeo = {'No': 'No', 'Yes': 'Sí', 'No internet service': 'Sin servicio de internet'}

for col in columnas_a_traducir:
    df[col] = df[col].replace(mapeo)

df.head()
# Out:
#            id Churn     genero  tiene +60 posee_pareja posee_dependientes  \
# 0  0002-ORFBO    No   Femenino          0           Sí                 Sí
# 1  0003-MKNFE    No  Masculino          0           No                 No
# 2  0004-TLHLJ    Sí  Masculino          0           No                 No
# 3  0011-IGKFF    Sí  Masculino          1           Sí                 No
# 4  0013-EXCHZ    Sí   Femenino          1           Sí                 No
#
#    tiempo_contrato servicio_telefono multiples_lineas tipo_internet  ...  \
# 0                9                Sí               No           DSL  ...
# 1                9                Sí               Sí           DSL  ...
# 2                4                Sí               No   Fiber optic  ...
# 3               13                Sí               No   Fiber optic  ...
# 4                3                Sí               No   Fiber optic  ...
#
#   proteccion_dispositivo soporte_tecnico streaming_tv streaming_peliculas  \
# 0                     No              Sí           Sí                  No
# 1                     No              No           No                  Sí
# 2                     Sí              No           No                  No
# 3                     Sí              No           Sí                  Sí
# 4                     No              Sí           Sí                  No
#
#   tipo_contrato factura_digital       metodo_pago valor_mensal total_cobrado  \
# 0         Anual             Yes      Mailed check         65.6        593.30
# 1       Mensual              No      Mailed check         59.9        542.40
# 2       Mensual             Yes  Electronic check         73.9        280.85
# 3       Mensual             Yes  Electronic check         98.0       1237.85
# 4       Mensual             Yes      Mailed check         83.9        267.40
#
#    cuentas_diarias
# 0         2.186667
# 1         1.996667
# 2         2.463333
# 3         3.266667
# 4         2.796667
#
# [5 rows x 22 columns]

# %%
df['metodo_pago'] = df['metodo_pago'].replace({
    'Mailed check': 'Cheque enviado por correo',
    'Electronic check': 'Cheque electrónico',
    'Credit card (automatic)': 'Tarjeta de crédito (automático)',
    'Bank transfer (automatic)': 'Transferencia bancaria (automática)'
})
df.head()
# Out:
#            id Churn     genero  tiene +60 posee_pareja posee_dependientes  \
# 0  0002-ORFBO    No   Femenino          0           Sí                 Sí
# 1  0003-MKNFE    No  Masculino          0           No                 No
# 2  0004-TLHLJ    Sí  Masculino          0           No                 No
# 3  0011-IGKFF    Sí  Masculino          1           Sí                 No
# 4  0013-EXCHZ    Sí   Femenino          1           Sí                 No
#
#    tiempo_contrato servicio_telefono multiples_lineas tipo_internet  ...  \
# 0                9                Sí               No           DSL  ...
# 1                9                Sí               Sí           DSL  ...
# 2                4                Sí               No   Fiber optic  ...
# 3               13                Sí               No   Fiber optic  ...
# 4                3                Sí               No   Fiber optic  ...
#
#   proteccion_dispositivo soporte_tecnico streaming_tv streaming_peliculas  \
# 0                     No              Sí           Sí                  No
# 1                     No              No           No                  Sí
# 2                     Sí              No           No                  No
# 3                     Sí              No           Sí                  Sí
# 4                     No              Sí           Sí                  No
#
#   tipo_contrato factura_digital                metodo_pago valor_mensal  \
# 0         Anual             Yes  Cheque enviado por correo         65.6
# 1       Mensual              No  Cheque enviado por correo         59.9
# 2       Mensual             Yes         Cheque electrónico         73.9
# 3       Mensual             Yes         Cheque electrónico         98.0
# 4       Mensual             Yes  Cheque enviado por correo         83.9
#
#   total_cobrado  cuentas_diarias
# 0        593.30         2.186667
# 1        542.40         1.996667
# 2        280.85         2.463333
# 3       1237.85         3.266667
# 4        267.40         2.796667
#
# [5 rows x 22 columns]

# %%
df
# Out:
#               id Churn     genero  tiene +60 posee_pareja posee_dependientes  \
# 0     0002-ORFBO    No   Femenino          0           Sí                 Sí
# 1     0003-MKNFE    No  Masculino          0           No                 No
# 2     0004-TLHLJ    Sí  Masculino          0           No                 No
# 3     0011-IGKFF    Sí  Masculino          1           Sí                 No
# 4     0013-EXCHZ    Sí   Femenino          1           Sí                 No
# ...          ...   ...        ...        ...          ...                ...
# 7262  9987-LUTYD    No   Femenino          0           No                 No
# 7263  9992-RRAMN    Sí  Masculino          0           Sí                 No
# 7264  9992-UJOEL    No  Masculino          0           No                 No
# 7265  9993-LHIEB    No  Masculino          0           Sí                 Sí
# 7266  9995-HOTOH    No  Masculino          0           Sí                 Sí
#
#       tiempo_contrato servicio_telefono          multiples_lineas  \
# 0                   9                Sí                        No
# 1                   9                Sí                        Sí
# 2                   4                Sí                        No
# 3                  13                Sí                        No
# 4                   3                Sí                        No
# ...               ...               ...                       ...
# 7262               13                Sí                        No
# 7263               22                Sí                        Sí
# 7264                2                Sí                        No
# 7265               67                Sí                        No
# 7266               63                No  Sin servicio de teléfono
#
#      tipo_internet  ... proteccion_dispositivo soporte_tecnico streaming_tv  \
# 0              DSL  ...                     No              Sí           Sí
# 1              DSL  ...                     No              No           No
# 2      Fiber optic  ...                     Sí              No           No
# 3      Fiber optic  ...                     Sí              No           Sí
# 4      Fiber optic  ...                     No              Sí           Sí
# ...            ...  ...                    ...             ...          ...
# 7262           DSL  ...                     No              Sí           No
# 7263   Fiber optic  ...                     No              No           No
# 7264           DSL  ...                     No              No           No
# 7265           DSL  ...                     Sí              Sí           No
# 7266           DSL  ...                     Sí              No           Sí
#
#      streaming_peliculas tipo_contrato factura_digital  \
# 0                     No         Anual             Yes
# 1                     Sí       Mensual              No
# 2                     No       Mensual             Yes
# 3                     Sí       Mensual             Yes
# 4                     No       Mensual             Yes
# ...                  ...           ...             ...
# 7262                  No         Anual              No
# 7263                  Sí       Mensual             Yes
# 7264                  No       Mensual             Yes
# 7265                  Sí        Bienal              No
# 7266                  Sí        Bienal              No
#
#                     metodo_pago valor_mensal total_cobrado  cuentas_diarias
# 0     Cheque enviado por correo        65.60        593.30         2.186667
# 1     Cheque enviado por correo        59.90        542.40         1.996667
# 2            Cheque electrónico        73.90        280.85         2.463333
# 3            Cheque electrónico        98.00       1237.85         3.266667
# 4     Cheque enviado por correo        83.90        267.40         2.796667
# ...                         ...          ...           ...              ...
# 7262  Cheque enviado por correo        55.15        742.90         1.838333
# 7263         Cheque electrónico        85.10       1873.70         2.836667
# 7264  Cheque enviado por correo        50.30         92.75         1.676667
# 7265  Cheque enviado por correo        67.85       4627.65         2.261667
# 7266         Cheque electrónico        59.00       3707.60         1.966667
#
# [7032 rows x 22 columns]

# %% [markdown]
# ## 📊 **Carga y análisis**

# %%
df.describe()
# Out:
#          tiene +60  tiempo_contrato  valor_mensal  total_cobrado  \
# count  7032.000000      7032.000000   7032.000000    7032.000000
# mean      0.162400        32.421786     64.798208    2283.300441
# std       0.368844        24.545260     30.085974    2266.771362
# min       0.000000         1.000000     18.250000      18.800000
# 25%       0.000000         9.000000     35.587500     401.450000
# 50%       0.000000        29.000000     70.350000    1397.475000
# 75%       0.000000        55.000000     89.862500    3794.737500
# max       1.000000        72.000000    118.750000    8684.800000
#
#        cuentas_diarias
# count      7032.000000
# mean          2.159940
# std           1.002866
# min           0.608333
# 25%           1.186250
# 50%           2.345000
# 75%           2.995417
# max           3.958333

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 12))
churn_counts = df['Churn'].value_counts()
churn_percentages = (churn_counts / len(df)) * 100

ax = churn_counts.plot(kind='bar')
plt.title('Distribuicion de Evasion de Clientes')
plt.xlabel('Cancelamiento')
plt.ylabel('Cantidad de Clientes')
plt.xticks(rotation=0)

for i, percentage in enumerate(churn_percentages):
    ax.text(i, churn_counts.iloc[i] + 50, f'{percentage:.1f}%', ha='center', va='bottom')

plt.show()

# %%
import plotly.express as px

# %%
px.histogram(df, x = 'genero', text_auto = True, color = 'Churn', barmode = 'group')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9c78d9e5-d0cd-4a9c-b9d0-6c5f32e720bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c78d9e5-d0cd-4a9c-b9d0-6c5f32e720bf")) {                    Plotly.newPlot(                        "9c78d9e5-d0cd-4a9c-b9d0-6c5f32e720bf",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No\u003cbr\u003egenero=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Femenino","Masculino","Femenino","Femenino","Masculino","Femenino","Femenino","Masculino","Femenino","Femenino","Femenino","Femenino","Femenino","Femenino","Femenino","Femenino","Femenino","Femenino","Femenino","Masculino","Masculino","Femenino","Masculino","Femenino","Masculino","Femenino","Masculino","Femenino","Femenino","Femenino","Femenino","Masculino","Femenino","Masculino","Masculino","Masculino","Masculino","Femenino","Femenino","Masculino","Masculino","Masculino","Femenino","Femenino","Femenino","Masculino","Masculino","Masculino","Femenino","Masculino","Masculino","Femenino","Masculino","Masculino","Femenino","Femenino","Femenino","Femenino","Masculino","Femenino","Femenino","Masculino","Masculino","Masculino","Femenino","Masculino","Femenino","Femenino","Masculino","Femenino","Femenino","Femenino","Femenino","Masculino","Masculino","Femenino","Masculino","Masculino","Masculino","Masculino","Femenino","
Fiber optic","Fiber optic","Fiber optic","DSL","DSL","DSL","DSL","Fiber optic","No","No","DSL","Fiber optic","No","DSL","No","DSL","Fiber optic","Fiber optic","Fiber optic","No","Fiber optic","DSL","DSL","No","DSL","Fiber optic","DSL","Fiber optic","DSL","Fiber optic","No","DSL","DSL","DSL","No","Fiber optic","No","No","DSL","Fiber optic","No","Fiber optic","No","No","Fiber optic","Fiber optic","DSL","DSL","Fiber optic","Fiber optic","DSL","No","Fiber optic","DSL","No","Fiber optic","DSL","Fiber optic","Fiber optic","DSL","Fiber optic","DSL","DSL","DSL","Fiber optic","No","Fiber optic","Fiber optic","Fiber optic","DSL","Fiber optic","DSL","DSL","No","No","DSL","No","Fiber optic","Fiber optic","Fiber optic","Fiber optic","No","Fiber optic","DSL","No","No","No","DSL","Fiber optic","No","DSL","Fiber optic","DSL","No","No","Fiber optic","No","Fiber optic","DSL","Fiber optic","No","Fiber optic","No","DSL","DSL","Fiber optic","DSL","Fiber optic","DSL","Fiber optic","No","DSL","Fiber optic","DSL","No","Fiber optic","DSL","DSL","DSL","No","DSL","No","DSL","Fiber optic","Fiber optic","DSL","DSL","Fiber optic","Fiber optic","Fiber optic","Fiber optic","Fiber optic","Fiber optic","Fiber optic","No","DSL","Fiber optic","No","Fiber optic","Fiber optic","DSL","DSL","No","DSL","DSL","No","No","Fiber optic","Fiber optic","No","No","Fiber optic","DSL","No","Fiber optic","DSL","No","No","DSL","No","Fiber optic","Fiber optic","Fiber optic","DSL","DSL","DSL","DSL","No","DSL","Fiber optic","Fiber optic","DSL","DSL","Fiber optic","No","No","Fiber optic","DSL","DSL","Fiber optic","Fiber optic","DSL","Fiber optic","Fiber optic","No","Fiber optic","DSL","DSL","Fiber optic","DSL","No","DSL","DSL","DSL","Fiber optic","Fiber optic", ...

# %%
px.histogram(df, x = 'metodo_pago',  text_auto = True, color = 'Churn', barmode = 'group')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="90882d4f-c14e-44b1-bb2c-2f05c5aeae68" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90882d4f-c14e-44b1-bb2c-2f05c5aeae68")) {                    Plotly.newPlot(                        "90882d4f-c14e-44b1-bb2c-2f05c5aeae68",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No\u003cbr\u003emetodo_pago=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Cheque enviado por correo","Cheque enviado por correo","Tarjeta de crédito (automático)","Transferencia bancaria (automática)","Tarjeta de crédito (automático)","Cheque electrónico","Cheque enviado por correo","Tarjeta de crédito (automático)","Tarjeta de crédito (automático)","Cheque electrónico","Transferencia bancaria (automática)","Transferencia bancaria (automática)","Tarjeta de crédito (automático)","Cheque enviado por correo","Cheque electrónico","Cheque electrónico","Cheque electrónico","Cheque enviado por correo","Transferencia bancaria (automática)","Tarjeta de crédito (automático)","Transferencia bancaria (automática)","Transferencia bancaria (automática)","Tarjeta de crédito (automático)","Transferencia bancaria (automática)","Transferencia bancaria (automática)","Cheque electrónico","Tarjeta de crédito (automático)","Cheque electrónico","Transferencia bancaria (automática)","Cheque electrónico","Transferencia bancaria (automática)","Transferencia bancaria (automática)","Cheque enviado por correo","Tarjeta de crédito (automático)","Transferencia bancaria (automática)","Cheque enviado por correo","Transferencia bancaria (automática)","Tarjeta de crédito (automático)","Cheque electrónico","Cheque enviado por correo","Cheque electrónico","Cheque electrónico","Tarjeta de crédito (automático)","Cheque electrónico","Cheque electrónico","Cheque enviado por correo","Cheque electrónico","Cheque electrónico","Transferencia bancaria (automática)","Tarjeta de crédito (automático)","Transferencia bancaria (automática)","Cheque electrónico","Cheque enviado por correo","Transferencia bancaria (automática)","Transferencia bancaria (automática)","Cheque electrónico","Transferencia bancaria (automática)","Tarjeta de crédito (automático)","Cheque enviado por correo","Cheque enviado por correo","Cheque enviado por correo","Cheque electrónico","Transferencia bancaria (automática)","Tarjeta de crédito (automático)","Transferencia bancaria (automática)","Cheque electrónico","Cheque electrónico","Transferencia bancaria (automática)","Cheque electrónico","Cheque electrónico","Cheque electrónico","Transferencia bancaria (automática)","Cheque electrónico","Tarjeta de crédito (automático)","Transferencia bancaria (automática)","Cheque enviado por correo","Cheque electrónico","Cheque enviado por correo","Transferencia bancaria (automática)","Cheque electrónico","Cheque enviado por correo","Cheque enviado por correo","Transferencia bancaria (automática)","Cheque electrónico","Tarjeta de crédito (automático)","Transferencia bancaria (automática)","Transferencia bancaria (automática)","Cheque enviado por correo","Cheque enviado por correo","Transferencia bancaria (automática)","Cheque electrónico","Transferencia bancaria (automática)","Tarjeta de crédito (automático)","Transferencia bancaria (automática)","Tarjeta de crédito (automático)","Transferencia bancaria (automática)","Cheque electrónico","Tarjeta de crédito (automático)","Cheque enviado por correo","Cheque electrónico","Cheque electrónico","Cheque electrónico","Transferencia bancaria (automática)","Transferenc ...
